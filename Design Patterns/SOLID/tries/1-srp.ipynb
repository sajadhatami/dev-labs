# %% [markdown]
# dirty code:

# %%
class User:
    def __init__(self, username, password):
        self.username = username
        self.password = password


    def register(self):
        print("Checking username...")
        print("Saving user to database...")


    def login(self):
        print("Checking password...")


    def send_welcome_email(self):
        print("Sending welcome email...")


    def create_profile_page(self):
        print("Creating HTML profile page...")

# %% [markdown]
# refactored code:

# %%
class User:
    def __init__(self, username, password):
        self.username = username
        self.password = password

class register:
    def register(self):
        print("Checking username...")
        print("Saving user to database...")

class login:
    def login(self):
        print("Checking password...")

class send_welcome_email:
    def send_welcome_email(self):
        print("Sending welcome email...")

class create_profile_page:
    def create_profile_page(self):
        print("Creating HTML profile page...")

# %% [markdown]
# dirty

# %%
class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price


    def calculate_discount(self, user):
        if user.is_vip:
            return self.price * 0.8
        return self.price


    def save_product(self):
        print("Saving product to database...")


    def send_product_email(self, email):
        print(f"Sending product info to {email}")


    def generate_report(self):
        print("Generating product sales report...")


    def check_inventory(self):
        print("Checking product stock...")


    def resize_product_image(self):
        print("Resizing image...")

# %% [markdown]
# refactored:

# %%
class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price

class ProductPrice:
    def __init__(self, price):
        self.price = price

    def calculate_discount(self, user):
        if user.is_vip:
            return self.price * 0.8
        return self.price

class CreateProduct:
    def save_product(self):
        print("Saving product to database...")

class ProductEmail:
    def send_product_email(self, email):
        print(f"Sending product info to {email}")

class ProductReport:
    def generate_report(self):
        print("Generating product sales report...")

class ProductInventory:
    def check_inventory(self):
        print("Checking product stock...")

class ProductImage:
    def resize_product_image(self):
        print("Resizing image...")

# %% [markdown]
# dirty:

# %%
class OrderService:
    def create_order(self, user, products):
        print("Checking product availability...")
        print("Calculating total price...")
        print("Saving order...")
        print("Sending confirmation email...")
        print("Updating warehouse...")
        print("Creating invoice...")

# %% [markdown]
# refactored:

# %%
class OrderService:
    def create_order(self, user, products):
        print("order added")
        
        
        
class inventoryService:
    def check_inventory(self):
        print("Checking product availability...")

class PricingService:
    def calculate_total_price(self, products):
        print("Calculating total price...")

class OrderProcessingService:
    def process_order(self, user, products):
        print("Saving order...")
        
class EmailService:
    def send_confirmation_email(self):
        print("Sending confirmation email...")
        
class WarehouseService:
    def update_warehouse(self):
        print("Updating warehouse...")

class InvoiceService:
    def create_invoice(self):
        print("Creating invoice...")
